# %%
# Clone the official pix2pix repository
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# %cd pytorch-CycleGAN-and-pix2pix

# Install required dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2516, done.
# remote: Total 2516 (delta 0), reused 0 (delta 0), pack-reused 2516 (from 1)
# Receiving objects: 100% (2516/2516), 8.20 MiB | 14.50 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.
# /content/pytorch-CycleGAN-and-pix2pix
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 93.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...

# %%
# Step 0: Clone the Pix2Pix repository again
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2516, done.
# remote: Total 2516 (delta 0), reused 0 (delta 0), pack-reused 2516 (from 1)
# Receiving objects: 100% (2516/2516), 8.20 MiB | 9.23 MiB/s, done.
# Resolving deltas: 100% (1575/1575), done.

# %%
# Step 1: Enter the repo folder
# %cd /content/pytorch-CycleGAN-and-pix2pix
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# Step 2: Install dependencies
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00
# ...

# %%
# !bash ./datasets/download_pix2pix_dataset.sh facades
# Out:
# Specified [facades]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2025-07-01 17:04:02--  http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/facades.tar.gz
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30168306 (29M) [application/x-gzip]
# Saving to: ‘./datasets/facades.tar.gz’
#
# ./datasets/facades. 100%[===================>]  28.77M   495KB/s    in 82s
#
# 2025-07-01 17:05:25 (361 KB/s) - ‘./datasets/facades.tar.gz’ saved [30168306/30168306]
#
# facades/
# facades/test/
# facades/test/27.jpg
# facades/test/5.jpg
# facades/test/72.jpg
# facades/test/1.jpg
# facades/test/10.jpg
# facades/test/100.jpg
# facades/test/101.jpg
# facades/test/102.jpg
# facades/test/103.jpg
# facades/test/104.jpg
# facades/test/105.jpg
# ...

# %%
# !python train.py --dataroot ./datasets/facades \
--name facades_pix2pix --model pix2pix \
--direction BtoA --n_epochs 10 --n_epochs_decay 0
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/facades            	[default: None]
#              dataset_mode: aligned
#                 direction: BtoA                          	[default: AtoB]
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
# ...

# %%
# !python test.py --dataroot ./datasets/facades \
--name facades_pix2pix --model pix2pix \
--direction BtoA
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: ./datasets/facades            	[default: None]
#              dataset_mode: aligned
#                 direction: BtoA                          	[default: AtoB]
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
# !ls results/facades_pix2pix/test_latest/images
# Out:
# 100_fake_B.png	13_fake_B.png  22_fake_B.png  31_fake_B.png  40_fake_B.png
# 100_real_A.png	13_real_A.png  22_real_A.png  31_real_A.png  40_real_A.png
# 100_real_B.png	13_real_B.png  22_real_B.png  31_real_B.png  40_real_B.png
# 101_fake_B.png	14_fake_B.png  23_fake_B.png  32_fake_B.png  41_fake_B.png
# 101_real_A.png	14_real_A.png  23_real_A.png  32_real_A.png  41_real_A.png
# 101_real_B.png	14_real_B.png  23_real_B.png  32_real_B.png  41_real_B.png
# 102_fake_B.png	15_fake_B.png  24_fake_B.png  33_fake_B.png  42_fake_B.png
# 102_real_A.png	15_real_A.png  24_real_A.png  33_real_A.png  42_real_A.png
# 102_real_B.png	15_real_B.png  24_real_B.png  33_real_B.png  42_real_B.png
# 103_fake_B.png	16_fake_B.png  25_fake_B.png  34_fake_B.png  43_fake_B.png
# 103_real_A.png	16_real_A.png  25_real_A.png  34_real_A.png  43_real_A.png
# 103_real_B.png	16_real_B.png  25_real_B.png  34_real_B.png  43_real_B.png
# 104_fake_B.png	17_fake_B.png  26_fake_B.png  35_fake_B.png  44_fake_B.png
# ...

# %%
from IPython.display import Image, display
import os

results_path = 'results/facades_pix2pix/test_latest/images'

# Show 3 sets of images (you can change the numbers if needed)
for i in [1, 2, 3]:
    print(f"\nResult {i}:")
    display(Image(filename=os.path.join(results_path, f'{i}_real_A.png')))   # Input
    display(Image(filename=os.path.join(results_path, f'{i}_fake_B.png')))   # Generated
    display(Image(filename=os.path.join(results_path, f'{i}_real_B.png')))   # Ground truth
# Out:
# Result 1:
# Result 2:
# Result 3:
